# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
from pandasql import sqldf
import statsmodels.formula.api as sm

# %matplotlib inline

# %%
pysqldf = lambda q: sqldf(q, globals())
movie_data = pickle.load(open("mojo_scrape.p", "rb" ))
movies_df = pd.DataFrame(movie_data)

# %% [markdown]
# We will grab movies made in the last ~25 years, and will only look at movies released before Nov 1 2014 so that the box office totals are reasonably accurate.  We need to grab them in two batches since the budgets are formatted differently for small and large budget movies.

# %%
def set_season(x):
    if x in [5,6,7]:
        return 'summer'
    elif x in [11,12]:
        return 'holiday'
    else:
        return 'off'

def get_movies_with_budget(movies_df):
    movies_df['budget_int'] = 0

    # These movies have budgets formatted: '$XX million'
    movies_budget_over_mil = pysqldf("   SELECT * FROM movies_df where \
                                    release_date > '1990-01-01 00:00:00' and release_date < '2014-11-01 00:00:00' \
                                    and budget like '%million%' \
                                    and widest_release >0;")

    # These movies have budgets formatted $X,XXX,XXX with the maximum value of one million
    movies_budget_under_mil = pysqldf("   SELECT * FROM movies_df where \
                                    release_date > '1990-01-01 00:00:00' and release_date < '2014-11-01 00:00:00' \
                                    and budget not like '%million%' and budget not like 'N/A' \
                                    and widest_release >0;")


    ### clean up the budgets, convert to INT

    for index,row in movies_budget_over_mil.iterrows():
        movies_budget_over_mil.ix[index,'budget_int'] = float(row['budget'].split()[0].replace('$',''))*1000000

    for index,row in movies_budget_under_mil.iterrows():
        movies_budget_under_mil.ix[index,'budget_int'] = float(row['budget'].replace('$','').replace(',',''))

    movies_df = movies_budget_over_mil.append(movies_budget_under_mil,ignore_index = True)
    
    ### add values that we will need for future processing
    movies_df['ones'] = 1.0
    movies_df['total_gross'] = 0.0

    for players in ['actors','directors','writers','producers']:
        movies_df[players] = ''
        
    movies_df['release_month'] = pd.DatetimeIndex(movies_df['release_date']).month
    movies_df['season'] = movies_df['release_month'].map(lambda x: set_season(x))
    
    return movies_df

def deflate_dollar_values(movies_df):


    ## we need these data to convert to 2014 dollars

    cpi = pd.read_csv('CPI-2005.csv')
    cpi['inflator'] = 0

    for index, row in cpi.iterrows():
        cpi.ix[index,'inflator'] = 121.2/row['CPI2005base']
        cpi.ix[index,'Date'] = row['Date'].split('/')[2]

    cpi_date_indexed = cpi.set_index('Date')


    ## convert all $ values to 2014 dollars

    for index,row in movies_df.iterrows():

        year = str(row['release_date'].year)

        if year in cpi.index.values:
            inflator = cpi_date_indexed.loc[year]['inflator']
            cpi.ix[index,'foreign_total_gross'] = row['foreign_total_gross']*inflator
            cpi.ix[index,'domestic_total_gross'] = row['domestic_total_gross']*inflator
            cpi.ix[index,'budget_int'] = row['budget_int']*inflator  

    ## calculate the total (worldwide) gross for a movie
    for index,row in movies_df.iterrows():
        movies_df.ix[index,'total_gross'] = row['domestic_total_gross'] + row['foreign_total_gross']


    movies_df['log_total_gross'] = np.log1p(movies_df['total_gross'])
    movies_df['log_domestic_gross'] = np.log1p(movies_df['domestic_total_gross'])
    movies_df['log_foreign_gross'] = np.log1p(movies_df['foreign_total_gross'])
    movies_df['log_budget'] = np.log1p(movies_df['budget_int'])
    movies_df['log_widest_release'] = np.log1p(movies_df['widest_release'])
    #movies_df['log_in_release'] = np.log1p(movies_df['in_release'])

    return movies_df

# %%
movies_df = get_movies_with_budget(movies_df)
movies_df = deflate_dollar_values(movies_df)

# %%
### this puts the playrs in their own column and semi-colon delimited
def separate_players(movies_df):
    for index,row in movies_df.iterrows():

        actors = []
        directors = []
        writers = []

        for player in row['players'].split(';'):
            player_type = player.split(':')[0]
            if player_type == 'Actor':
                actors.append('actor_'+player.split(':')[1].replace(" ", "").replace(".","").replace("&",""))
            elif player_type == 'Director':
                directors.append('director_'+player.split(':')[1].replace(" ", "").replace(".","").replace("&",""))
            elif player_type == 'Writer':
                writers.append('writer_'+player.split(':')[1].replace(" ", "").replace(".","").replace("&",""))

        movies_df.ix[index, 'actors'] = ';'.join(actors)
        movies_df.ix[index, 'directors'] =  ';'.join(directors)
        movies_df.ix[index, 'writers'] =  ';'.join(writers)
        
    return movies_df

# %%
import operator

### count the genres in the model
def add_genres_columns(movies_df, min_occurances=20):
    genres_count = {}

    for index,row in movies_df.iterrows():

        for genre in row['genres'].split(';'):
            if len(genre.split()):
                genre_movie = genre.split()[0]
                if genre_movie not in genres_count.keys():
                    genres_count[genre_movie] = 1
                else:
                    genres_count[genre_movie] = genres_count[genre_movie] + 1

    model_genres = []
    sorted_genres = sorted(genres_count.items(), key=operator.itemgetter(1), reverse=True)
    for genre in sorted_genres:
        if genre[1]>=min_occurances:
            model_genres.append(genre[0])

    ### and this adds them to the model
    for genre in model_genres:
        movies_df[genre] = 0
        
        
    # adds the genres
    for index,row in movies_df.iterrows():

        for genre in row['genres'].split(';'):
            if len(genre.split()):
                genre_movie = genre.split()[0]
                for model_genre in model_genres:
                    if genre_movie == model_genre:
                        movies_df.ix[index, model_genre] = 1

    return movies_df, model_genres

# %%
movies_df = separate_players(movies_df)

# %%
movies_df, model_genres = add_genres_columns(movies_df)

# %%
def dummify_players(movies_df,min_occurances=5):
    
    ### this creates a dictionary of all of the players in our dataset

    all_actors = {}
    all_directors = {}
    all_writers = {}

    for index,row in movies_df.iterrows():

        for writer in row['writers'].split(';'):
            if writer != '':
                if writer not in all_writers.keys():
                    all_writers[writer] = 1
                else:
                    all_writers[writer] = all_writers[writer] + 1

        for actor in row['actors'].split(';'):
            if actor != '':
                if actor not in all_actors.keys():
                    all_actors[actor] = 1
                else:
                    all_actors[actor] = all_actors[actor] + 1

        for director in row['directors'].split(';'):
            if director != '':
                if director not in all_directors.keys():
                    all_directors[director] = 1
                else:
                    all_directors[director] = all_directors[director] + 1


    ###this creates a list of writers that will be added to the model
    model_writers = []
    sorted_writers = sorted(all_writers.items(), key=operator.itemgetter(1), reverse=True)

    for writer in sorted_writers:
        if writer[1]>=min_occurances:
            model_writers.append(writer[0])

    for writer in model_writers:
        movies_df[writer] = 0


    for index,row in movies_df.iterrows():
        for movie_writer in row['writers'].split(';'):
            for model_writer in model_writers:
                if movie_writer == model_writer:
                    movies_df.ix[index, model_writer] = 1


    ###this creates a list of actors that will be added to the model
    model_actors = []
    sorted_actors = sorted(all_actors.items(), key=operator.itemgetter(1), reverse=True)

    for actor in sorted_actors:
        if actor[1] >= min_occurances:
            model_actors.append(actor[0])

    for actor in model_actors:
        movies_df[actor] = 0


    for index,row in movies_df.iterrows():
        for movie_actor in row['actors'].split(';'):
            for model_actor in model_actors:
                if movie_actor == model_actor:
                    movies_df.ix[index, model_actor] = 1


    ###this creates a list of directors that will be added to the model
    model_directors = []
    sorted_directors = sorted(all_directors.items(), key=operator.itemgetter(1), reverse=True)

    for director in sorted_directors:
        if director[1] >= min_occurances:
            model_directors.append(director[0])


    for director in model_directors:
        movies_df[director] = 0



    for index,row in movies_df.iterrows():
        for movie_director in row['directors'].split(';'):
            for model_director in model_directors:
                if movie_director == model_director:
                    movies_df.ix[index, model_director] = 1
                    
    return movies_df, model_actors, model_directors, model_writers

# %%
print len(movies_df.columns)
movies_df, model_actors, model_directors, model_writers = dummify_players(movies_df,5)
print len(model_actors)
print len(model_directors)
print len(model_writers)
print len(movies_df.columns)
# Out:
# 82
# 559
# 112
# 114
# 867

# %%
model_ratings =  ['rating_G','rating_PG','rating_PG-13','rating_R']
dummy_ratings = pd.get_dummies(movies_df['rating'], prefix='rating')
movies_df = movies_df.join(dummy_ratings[model_ratings])

model_seasons =  ['season_summer','season_holiday']
dummy_seasons = pd.get_dummies(movies_df['season'], prefix='season')
movies_df = movies_df.join(dummy_seasons[model_seasons])

# %%
from sklearn.linear_model import LinearRegression
from sklearn import linear_model

# %%
#model_actors + model_directors + model_writers

# %%
# regr = LinearRegression()
# regr.fit(X,y)

# rcv = linear_model.Ridge(fit_intercept=True)
# rcv.fit(X,y)

# las = linear_model.Lasso(fit_intercept=True)
# las.fit(X,y)

# %%
y_cols = ['budget_int','widest_release','ones'] + model_ratings + model_seasons

y = movies_df['total_gross']
X = movies_df[y_cols]
linmodel_min5apps = sm.OLS(y, X).fit()
linmodel_min5apps.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            total_gross   R-squared:                       0.536
# Model:                            OLS   Adj. R-squared:                  0.535
# Method:                 Least Squares   F-statistic:                     380.9
# Date:                Fri, 27 Feb 2015   Prob (F-statistic):               0.00
# Time:                        18:16:14   Log-Likelihood:                -52945.
# No. Observations:                2642   AIC:                         1.059e+05
# Df Residuals:                    2633   BIC:                         1.060e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# budget_int         2.1250      0.075     28.268      0.000         1.978     2.272
# widest_release  3.613e+04   2771.704     13.037      0.000      3.07e+04  4.16e+04
# ones           -2.104e+07   1.56e+07     -1.348      0.178     -5.17e+07  9.57e+06
# rating_G       -1.457e+07   2.23e+07     -0.653      0.514     -5.83e+07  2.92e+07
# rating_PG      -5.384e+07   1.77e+07     -3.045      0.002     -8.85e+07 -1.92e+07
# rating_PG-13   -4.818e+07   1.69e+07     -2.848      0.004     -8.14e+07  -1.5e+07
# rating_R       -4.679e+07   1.64e+07     -2.846      0.004      -7.9e+07 -1.46e+07
# season_summer   5.316e+07   6.23e+06      8.529      0.000      4.09e+07  6.54e+07
# season_holiday  3.371e+07   6.38e+06      5.285      0.000      2.12e+07  4.62e+07
# ==============================================================================
# Omnibus:                     1886.182   Durbin-Watson:                   1.705
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            59299.116
# Skew:                           2.987   Prob(JB):                         0.00
# Kurtosis:                      25.427   Cond. No.                     9.57e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.57e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
y_cols = ['log_budget','log_widest_release','ones'] + model_ratings + model_seasons

y = movies_df['log_total_gross']
X = movies_df[y_cols]
linmodel_min5apps = sm.OLS(y, X).fit()
linmodel_min5apps.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        log_total_gross   R-squared:                       0.781
# Model:                            OLS   Adj. R-squared:                  0.780
# Method:                 Least Squares   F-statistic:                     1171.
# Date:                Fri, 27 Feb 2015   Prob (F-statistic):               0.00
# Time:                        18:20:01   Log-Likelihood:                -3868.5
# No. Observations:                2642   AIC:                             7755.
# Df Residuals:                    2633   BIC:                             7808.
# Df Model:                           8
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# log_budget             0.2790      0.020     13.645      0.000         0.239     0.319
# log_widest_release     1.0239      0.018     56.116      0.000         0.988     1.060
# ones                   5.5596      0.285     19.537      0.000         5.002     6.118
# rating_G              -0.4009      0.200     -2.001      0.046        -0.794    -0.008
# rating_PG             -0.5743      0.162     -3.554      0.000        -0.891    -0.257
# rating_PG-13          -0.4856      0.157     -3.095      0.002        -0.793    -0.178
# rating_R              -0.4443      0.151     -2.941      0.003        -0.740    -0.148
# season_summer          0.6381      0.052     12.319      0.000         0.537     0.740
# season_holiday         0.5248      0.054      9.647      0.000         0.418     0.631
# ==============================================================================
# Omnibus:                      131.670   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              411.071
# Skew:                          -0.173   Prob(JB):                     5.46e-90
# Kurtosis:                       4.901   Cond. No.                         306.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y_cols = ['budget_int','widest_release','ones'] + model_ratings + model_seasons

y = movies_df['log_total_gross']
X = movies_df[y_cols]
linmodel_min5apps = sm.OLS(y, X).fit()
linmodel_min5apps.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        log_total_gross   R-squared:                       0.689
# Model:                            OLS   Adj. R-squared:                  0.688
# Method:                 Least Squares   F-statistic:                     727.8
# Date:                Fri, 27 Feb 2015   Prob (F-statistic):               0.00
# Time:                        18:38:39   Log-Likelihood:                -4331.4
# No. Observations:                2642   AIC:                             8681.
# Df Residuals:                    2633   BIC:                             8734.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------
# budget_int      3.136e-09   7.67e-10      4.088      0.000      1.63e-09  4.64e-09
# widest_release     0.0014   2.83e-05     48.361      0.000         0.001     0.001
# ones              11.8571      0.159     74.436      0.000        11.545    12.169
# rating_G           2.2594      0.228      9.920      0.000         1.813     2.706
# rating_PG          1.9340      0.180     10.721      0.000         1.580     2.288
# rating_PG-13       2.2806      0.173     13.212      0.000         1.942     2.619
# rating_R           2.4196      0.168     14.425      0.000         2.091     2.749
# season_summer      0.3776      0.064      5.937      0.000         0.253     0.502
# season_holiday     0.7593      0.065     11.665      0.000         0.632     0.887
# ==============================================================================
# Omnibus:                      512.838   Durbin-Watson:                   1.965
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2834.928
# Skew:                          -0.805   Prob(JB):                         0.00
# Kurtosis:                       7.813   Cond. No.                     9.57e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.57e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#zip(y_cols, regr.coef_, las.coef_, rcv.coef_)
by_month = movies_df.groupby('release_month')

# %%
by_month.mean()[['domestic_total_gross','foreign_total_gross']].plot(kind='bar')

# %%
by_month.mean()[['domestic_total_gross','foreign_total_gross']].plot(kind='bar', stacked=True)

# %%
by_month.mean()[['total_gross']].plot(kind='bar')

# %%
from pandas.tools.plotting import scatter_matrix

# %%
by_month.mean()[['runtime_mins']].plot()

# %%
by_rating = movies_df.groupby('rating')
by_rating.mean()[['total_gross']].plot(kind='bar')

# %%
scatter_matrix(movies_df[['budget_int','widest_release','domestic_total_gross','foreign_total_gross']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x13a8bd7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13aa10250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13aab6510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13ab19590>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x13ab9b7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13ab525d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13ac82f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13ad12090>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x13ad77310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13adfb110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13ae48a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13aed5cd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x13af59a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13afc8390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13b04c5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13b0a5f50>]], dtype=object)

# %%
scatter_matrix(movies_df[['log_budget','log_widest_release','log_total_gross']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x13b230710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13b5b5750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13b65ba50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x13b6c1910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13b743b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13b6fa790>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x13b8362d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13b8b8410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13b91d690>]], dtype=object)

# %%
all_models = {}

#initial model (cols to ALWAYS keep)
x_cols_model = ['log_budget','log_widest_release','ones'] + model_seasons # + model_ratings
x_cols_test = model_genres

# the cols we are adding are the cols to test and potentially eliminate
x_cols = x_cols_model + x_cols_test

y = movies_df['log_total_gross']
X = movies_df[x_cols]

linmodel = sm.OLS(y, X).fit()
all_models['initial'] = [linmodel,x_cols]

#now we have our baseline model, let's iterate
num = math.ceil(math.log(len(x_cols)))
p_val_thresholds = np.linspace(.5,.05,num)

for p_val in p_val_thresholds:
    
    print p_val
    
    cols_to_keep = []
    
    for coef in linmodel.pvalues.iteritems():
        if coef[0] not in x_cols_model:
            if coef[1] < p_val:
                cols_to_keep.append(coef[0])
    
    
    x_cols = x_cols_model + cols_to_keep
    y = movies_df['log_total_gross']
    X = movies_df[x_cols]

    linmodel = sm.OLS(y, X).fit()
    all_models[p_val] = [linmodel,x_cols]

model_genres = cols_to_keep
linmodel.summary()
# Out:
# 0.5
# 0.275
# 0.05
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        log_total_gross   R-squared:                       0.804
# Model:                            OLS   Adj. R-squared:                  0.803
# Method:                 Least Squares   F-statistic:                     599.0
# Date:                Sat, 28 Feb 2015   Prob (F-statistic):               0.00
# Time:                        18:36:04   Log-Likelihood:                -3717.7
# No. Observations:                2642   AIC:                             7473.
# Df Residuals:                    2623   BIC:                             7585.
# Df Model:                          18
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# log_budget             0.2259      0.020     11.271      0.000         0.187     0.265
# log_widest_release     1.0408      0.017     62.210      0.000         1.008     1.074
# ones                   5.7626      0.273     21.072      0.000         5.226     6.299
# season_summer          0.5937      0.049     12.093      0.000         0.497     0.690
# season_holiday         0.5087      0.052      9.811      0.000         0.407     0.610
# Animation              0.2130      0.090      2.362      0.018         0.036     0.390
# Sports                -0.3573      0.106     -3.359      0.001        -0.566    -0.149
# 3D                     0.2976      0.097      3.054      0.002         0.107     0.489
# IMAX                   0.5486      0.103      5.336      0.000         0.347     0.750
# Travelogue             0.3293      0.094      3.490      0.000         0.144     0.514
# Spy                    0.3110      0.137      2.265      0.024         0.042     0.580
# Foreign                1.9752      0.158     12.509      0.000         1.666     2.285
# Gay                    0.5766      0.163      3.540      0.000         0.257     0.896
# Young-Adult            0.5394      0.178      3.033      0.002         0.191     0.888
# Documentary            0.4528      0.214      2.112      0.035         0.032     0.873
# CGI                    0.5106      0.190      2.694      0.007         0.139     0.882
# Western               -0.4294      0.189     -2.267      0.023        -0.801    -0.058
# Controversy            0.6776      0.191      3.556      0.000         0.304     1.051
# Prequel                0.5020      0.209      2.402      0.016         0.092     0.912
# ==============================================================================
# Omnibus:                      142.771   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              438.513
# Skew:                          -0.220   Prob(JB):                     6.00e-96
# Kurtosis:                       4.947   Cond. No.                         272.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
all_models = {}

#initial model (cols to ALWAYS keep)
x_cols_model = ['log_budget','log_widest_release','ones'] + model_seasons + model_genres
x_cols_test = model_actors + model_directors + model_writers



x_cols_test.remove('writer_JoelCoen')
x_cols_test.remove('writer_EthanCoen')

# the cols we are adding are the cols to test and potentially eliminate
x_cols = x_cols_model + x_cols_test

y = movies_df['log_total_gross']
X = movies_df[x_cols]

linmodel = sm.OLS(y, X).fit()
all_models['initial'] = [linmodel,x_cols]

#now we have our baseline model, let's iterate
num = math.ceil(math.log(len(x_cols)))
p_val_thresholds = np.linspace(.3,.05,num)

for p_val in p_val_thresholds:
    
    print p_val
    
    cols_to_keep = []
    
    for coef in linmodel.pvalues.iteritems():
        if coef[0] not in x_cols_model:
            if coef[1] < p_val:
                cols_to_keep.append(coef[0])
    
    
    x_cols = x_cols_model+cols_to_keep
    y = movies_df['log_total_gross']
    X = movies_df[x_cols]

    linmodel = sm.OLS(y, X).fit()
    all_models[p_val] = [linmodel,x_cols]

print linmodel.summary()
# Out:
# 0.3
# 0.258333333333
# 0.216666666667
# 0.175
# 0.133333333333
# 0.0916666666667
# 0.05
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        log_total_gross   R-squared:                       0.830
# Model:                            OLS   Adj. R-squared:                  0.824
# Method:                 Least Squares   F-statistic:                     141.4
# Date:                Sun, 01 Mar 2015   Prob (F-statistic):               0.00
# Time:                        16:35:08   Log-Likelihood:                -3533.4
# No. Observations:                2642   AIC:                             7245.
# Df Residuals:                    2553   BIC:                             7768.
# Df Model:                          88
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------
# log_budget                     0.1742      0.020      8.863      0.000         0.136     0.213
# log_widest_release             1.0522      0.016     65.577      0.000         1.021     1.084
# ones                           6.4531      0.268     24.077      0.000         5.928     6.979
# season_summer                  0.5349      0.047     11.266      0.000         0.442     0.628
# season_holiday                 0.3941      0.051      7.788      0.000         0.295     0.493
# Animation                      0.2195      0.090      2.440      0.015         0.043     0.396
# Sports                        -0.2676      0.102     -2.634      0.008        -0.467    -0.068
# 3D                             0.3304      0.093      3.541      0.000         0.147     0.513
# IMAX                           0.4940      0.099      4.977      0.000         0.299     0.689
# Travelogue                     0.2512      0.091      2.758      0.006         0.073     0.430
# Spy                            0.2774      0.135      2.059      0.040         0.013     0.541
# Foreign                        2.0892      0.150     13.970      0.000         1.796     2.382
# Gay                            0.5222      0.155      3.363      0.001         0.218     0.827
# Young-Adult                    0.1871      0.201      0.931      0.352        -0.207     0.581
# Documentary                    0.4681      0.203      2.307      0.021         0.070     0.866
# CGI                            0.6358      0.188      3.387      0.001         0.268     1.004
# Western                       -0.5032      0.186     -2.704      0.007        -0.868    -0.138
# Controversy                    0.5709      0.185      3.086      0.002         0.208     0.934
# actor_IoanGruffudd             0.7246      0.316      2.292      0.022         0.105     1.345
# actor_JohnSlattery            -0.4798      0.346     -1.387      0.166        -1.158     0.199
# actor_MichelleWilliams         0.7446      0.346      2.155      0.031         0.067     1.422
# actor_RandyQuaid              -0.7674      0.345     -2.223      0.026        -1.444    -0.090
# actor_WillForte               -0.8138      0.340     -2.396      0.017        -1.480    -0.148
# actor_RupertGrint              1.5329      0.394      3.891      0.000         0.760     2.305
# actor_NickFrost                0.7313      0.361      2.024      0.043         0.023     1.440
# actor_SachaBaronCohen          0.7114      0.364      1.953      0.051        -0.003     1.426
# actor_JessicaChastain          0.8867      0.362      2.448      0.014         0.177     1.597
# actor_MNightShyamalan          0.8436      0.425      1.985      0.047         0.010     1.677
# actor_LanceReddick            -0.9173      0.429     -2.139      0.033        -1.758    -0.076
# actor_LennyKravitz             0.9467      0.429      2.209      0.027         0.106     1.787
# actor_RomolaGarai              0.8865      0.430      2.063      0.039         0.044     1.729
# director_StevenSpielberg       0.8789      0.253      3.480      0.001         0.384     1.374
# director_MichaelBay            0.5087      0.298      1.709      0.088        -0.075     1.092
# director_GoreVerbinski         1.0088      0.319      3.167      0.002         0.384     1.633
# director_DavidFincher          0.9285      0.316      2.935      0.003         0.308     1.549
# director_ToddPhillips          0.6227      0.337      1.847      0.065        -0.038     1.284
# director_RolandEmmerich        0.8389      0.340      2.469      0.014         0.173     1.505
# director_DavidORussell         0.8110      0.384      2.110      0.035         0.057     1.564
# director_CarlosSaldanha        1.1506      0.392      2.932      0.003         0.381     1.920
# director_RobReiner            -0.9038      0.401     -2.252      0.024        -1.691    -0.117
# director_BarryLevinson        -0.7285      0.389     -1.875      0.061        -1.490     0.033
# director_DannyBoyle            1.4308      0.386      3.710      0.000         0.675     2.187
# director_RomanPolanski         0.8256      0.430      1.921      0.055        -0.017     1.668
# director_JoelCoen              1.0067      0.424      2.376      0.018         0.176     1.838
# writer_ChrisSanders            1.2571      0.393      3.200      0.001         0.487     2.027
# writer_LeighWhannell           0.8137      0.395      2.059      0.040         0.039     1.589
# writer_LeslieDixon             0.9237      0.384      2.407      0.016         0.171     1.676
# writer_MelissaRosenberg        1.1933      0.418      2.858      0.004         0.374     2.012
# writer_ChrisMorgan             0.9186      0.384      2.390      0.017         0.165     1.672
# writer_PaulWSAnderson          0.5506      0.387      1.425      0.154        -0.207     1.309
# ==============================================================================
# Omnibus:                      173.943   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              675.279
# Skew:                          -0.205   Prob(JB):                    2.32e-147
# Kurtosis:                       5.443   Cond. No.                         478.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
coefs = pd.DataFrame(linmodel.params)

player_coefs = coefs.ix[x_cols_test].dropna()
player_coefs["exp^coeff"] = player_coefs[0].map(lambda x: math.exp(x))
player_coefs.sort('exp^coeff')['exp^coeff'].plot(kind='bar')
plt.xlabel(a)
print len(player_coefs)
# Out:
# 72

# %%
all_models = {}

#initial model (cols to ALWAYS keep)
x_cols_model = ['log_budget','log_widest_release','ones'] + model_seasons + model_genres
x_cols_test = model_actors + model_directors + model_writers

# the cols we are adding are the cols to test and potentially eliminate
x_cols = x_cols_model + x_cols_test

y = movies_df['total_gross']
X = movies_df[x_cols]

linmodel = sm.OLS(y, X).fit()
all_models['initial'] = [linmodel,x_cols]

#now we have our baseline model, let's iterate
num = math.ceil(math.log(len(x_cols)))
p_val_thresholds = np.linspace(.3,.05,num)

for p_val in p_val_thresholds:
    
    print p_val
    
    cols_to_keep = []
    
    for coef in linmodel.pvalues.iteritems():
        if coef[0] not in x_cols_model:
            if coef[1] < p_val:
                cols_to_keep.append(coef[0])
    
    
    x_cols = x_cols_model+cols_to_keep
    y = movies_df['total_gross']
    X = movies_df[x_cols]

    linmodel = sm.OLS(y, X).fit()
    all_models[p_val] = [linmodel,x_cols]

print linmodel.summary()
# Out:
# 0.3
# 0.258333333333
# 0.216666666667
# 0.175
# 0.133333333333
# 0.0916666666667
# 0.05
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            total_gross   R-squared:                       0.650
# Model:                            OLS   Adj. R-squared:                  0.632
# Method:                 Least Squares   F-statistic:                     35.09
# Date:                Sat, 28 Feb 2015   Prob (F-statistic):               0.00
# Time:                        18:30:18   Log-Likelihood:                -52573.
# No. Observations:                2642   AIC:                         1.054e+05
# Df Residuals:                    2508   BIC:                         1.062e+05
# Df Model:                         133
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------
# log_budget                  1.183e+07   2.29e+06      5.175      0.000      7.35e+06  1.63e+07
# log_widest_release          1.323e+07   1.86e+06      7.105      0.000      9.58e+06  1.69e+07
# ones                        -2.55e+08   3.13e+07     -8.146      0.000     -3.16e+08 -1.94e+08
# season_summer               6.604e+07   5.62e+06     11.748      0.000       5.5e+07  7.71e+07
# season_holiday               2.36e+07   5.96e+06      3.960      0.000      1.19e+07  3.53e+07
# Animation                   5.998e+07   1.09e+07      5.495      0.000      3.86e+07  8.14e+07
# Sports                     -2.652e+07   1.18e+07     -2.239      0.025     -4.97e+07  -3.3e+06
# 3D                          8.737e+07   1.11e+07      7.843      0.000      6.55e+07  1.09e+08
# IMAX                        1.312e+08   1.23e+07     10.647      0.000      1.07e+08  1.55e+08
# Travelogue                  3.268e+07   1.06e+07      3.069      0.002      1.18e+07  5.36e+07
# Spy                         4.958e+07   1.66e+07      2.985      0.003       1.7e+07  8.22e+07
# Foreign                      2.21e+07   1.76e+07      1.254      0.210     -1.24e+07  5.67e+07
# Gay                        -9.382e+06   1.83e+07     -0.514      0.607     -4.52e+07  2.64e+07
# Young-Adult                 6.518e+07   2.46e+07      2.654      0.008       1.7e+07  1.13e+08
# Documentary                 1.194e+07   2.37e+07      0.505      0.614     -3.45e+07  5.83e+07
# CGI                         1.681e+08   2.33e+07      7.200      0.000      1.22e+08  2.14e+08
# Western                    -2.311e+07   2.13e+07     -1.085      0.278     -6.49e+07  1.87e+07
# Controversy                 7.259e+07   2.16e+07      3.367      0.001      3.03e+07  1.15e+08
# Prequel                     1.292e+08   2.36e+07      5.464      0.000      8.28e+07  1.76e+08
# actor_SamuelLJackson        9.986e+07   1.75e+07      5.699      0.000      6.55e+07  1.34e+08
